# %%
student=()

# %%
def add_student():
    student_id=input("enter your ID")
    return
name=input("enter your name")
grade=float(input("enter your grade"))
student[student_id]={
    "name": name,
    "grade": grade,}

print("students added")

def show_students():
    return
for studentId,info in student.item():
    print("ID",studentId)
    print("name",info["name"])
    print("grade",info["grade"])

def search_students():
    return
student_id=input("enter student ID")
if student_id in students:
    print("ID",student_id)
    print("name",students[student_id]["name"])
    print("grade",students[student_id]["grade"])
else:
    print("student not found")

def update_grade():
    students_id=input("ente your ID")
    if student_id in students:
        students[student_id]["grade"]
        float(input("enter the new grade"))
    else:
    print("student not found")

def delete_student():
    student_id=input("enter student ID")
    if student_id in students:
        del students[students_id]
        print("student_deleted")
    else:
        print("student not found")

def average_grade():
    sum=0
    for student in students:
        sum=sum+students["grade"]
        average=sum/len(students)
        print("average grade =", average)        

def best_student():
    best_grade = 0

    for student_id, info in enumerate(students):
        if info["grade"] > best_grade:
            best_grade = info["grade"]
            Id = student_id

    print("id", Id)
    print("name", students[Id]["name"])
    print("grade", students[Id]["grade"])

def worst_student():
    worst_grade = 100

    for student_id, info in enumerate(students):
        if info["grade"] < worst_grade:
            worst_grade = info["grade"]
            Id = student_id

    print("id", Id)
    print("name", students[Id]["name"])
    print("grade", students[Id]["grade"])

def total_students():
    print(len(students))    

def passed_students():
    for ID, info in enumerate(students):
        if info["grade"] >= 60:
            print(ID, info["name"], info["grade"])

def failed_students():
    for ID, info in enumerate(students):
        if info["grade"] < 60:
            print(ID, info["name"], info["grade"])                

while True:

    print("1/ add student")
    print("2/ show all students")
    print("3/ search for student")
    print("4/ update student grade")
    print("5/ delete student")
    print("6/ average grade")
    print("7/ best student")
    print("8/ worst student")
    print("9/ total number of students")
    print("10/ passed student")
    print("11/ failed student")
    print("12/ EXIT")

    choice = int(input("enter your choice "))

    if choice == 1:
        add_student()

    elif choice == 2:
        show_students()

    elif choice == 3:
        search_students()

    elif choice == 4:
        update_grade()

    elif choice == 5:
        delete_student()

    elif choice == 6:
        average_grade()

    elif choice == 7:
        best_student()

    elif choice == 8:
        worst_student()

    elif choice == 9:
        total_students()

    elif choice == 10:
        passed_students()

    elif choice == 11:
        failed_students()

    elif choice == 12:
        break

    else:
        print("invalid choice")
